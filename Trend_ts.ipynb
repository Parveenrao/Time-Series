# %% [raw]
# import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
pip install statsmodels
# Out:
# ...
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Parveen\anaconda3\Lib\site-packages)
# DEPRECATION: Loading egg at c:\users\parveen\anaconda3\lib\site-packages\machine_learning_project-0.0.1-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Parveen\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~andas (C:\Users\Parveen\anaconda3\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import statsmodels

# %%
date_range = pd.date_range(start = "2020-01-01" , periods = 100 , freq = "d")
upward_trend = np.linspace(10 , 60 ,100) + np.random.normal(0,2,100)  # linspace --> create equally spaced values start from 10 and end at 60
ts_up = pd.Series(upward_trend , index = date_range)

# %%
ts_up
# Out:
# 2020-01-01    13.858713
# 2020-01-02     9.457982
# 2020-01-03    10.481600
# 2020-01-04    10.728699
# 2020-01-05     9.576542
#                 ...
# 2020-04-05    60.581089
# 2020-04-06    58.449035
# 2020-04-07    58.972112
# 2020-04-08    61.343424
# 2020-04-09    57.028122
# Freq: D, Length: 100, dtype: float64

# %%
# downward trend
date_range2 = pd.date_range(start = '2020-01-01' , periods = 100 , freq = "d")
downward_trend = np.linspace(60 , 10 , 100) + np.random.normal(0 ,2, 100)
ts_down = pd.Series(downward_trend , index  = date_range2)

# %%
ts_down
# Out:
# 2020-01-01    58.539147
# 2020-01-02    60.246825
# 2020-01-03    61.319640
# 2020-01-04    61.976567
# 2020-01-05    59.991146
#                 ...
# 2020-04-05    13.136036
# 2020-04-06    11.551096
# 2020-04-07    12.454521
# 2020-04-08     8.309950
# 2020-04-09     6.365096
# Freq: D, Length: 100, dtype: float64

# %%
# plot both the trend together

plt.figure(figsize = (6 ,6))
plt.plot(ts_up , label = 'Upward_trend' , color = 'green')
plt.plot(ts_down , label = 'Down_trend' , color = 'red')
plt.title('Trend In Time Series Analysis')
plt.legend()
plt.show()
